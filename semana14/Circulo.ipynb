# %%
#variables y librerias 
import matplotlib.pyplot as plt
import numpy as np

#longitud de caja
long=10

# %% [markdown]
# # Ejercicio 1

# %%
x=np.random.rand(1)
y=np.random.rand(1)
z=np.array([x,y]).T
plt.scatter(x,y)

# %%
for i in range (0,360,10):
    a=x+np.cos(i)
    b=y+np.sin(i)
    
    plt.scatter(a,b)
    plt.scatter(x,y)

# %%
x=np.random.rand(10)
y=np.random.rand(10)
s=np.random.rand(15)
o=np.random.rand(15)
z=np.array([x,y]).T
so=np.array([s,o]).T
plt.scatter(x,y)
plt.scatter(s,o)

# %%
for i in range (0,360,10):
    a=x+np.cos(i)
    b=y+np.sin(i)
    
    plt.scatter(a,b)
    plt.scatter(x,y)
    plt.scatter(s,o)

# %%
for i in range (0,360,10):           #Aquí se aprecia de una manera más visual, aunque dsiminui la escala del circulo.
    a=x+(np.cos(i))/10
    b=y+(np.sin(i))/10     
    
    plt.scatter(a,b)
    plt.scatter(x,y)
    plt.scatter(s,o)
